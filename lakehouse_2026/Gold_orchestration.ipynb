# %% [markdown]
# #
# Gold Layer Orchestration

# %%
notebooks = [
    "/Workspace/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Gold/Gold_dim_customers",
    "/Workspace/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Gold/Gold_dim_products",
    "/Workspace/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Gold/Gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
