# %% [markdown]
# # Initialization

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StringType
from pyspark.sql.functions import col, trim

# %% [markdown]
# # Reading Bronze Table

# %%
df = spark.table("workspace.bronze.crm_sales_details")

# %% [markdown]
# #Data Transformations

# %% [markdown]
# ## Trimming

# %%
for field in df.schema.fields:
  if isinstance(field.dataType, StringType):
    df = df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ## Changing Data Type

# %%
df = (
    df
    .withColumn(
        "sls_order_dt",
        F.try_to_date(F.col("sls_order_dt").cast("string"), "yyyyMMdd")
    )
    .withColumn(
        "sls_ship_dt",
        F.try_to_date(F.col("sls_ship_dt").cast("string"), "yyyyMMdd")
    )
    .withColumn(
        "sls_due_dt",
        F.try_to_date(F.col("sls_due_dt").cast("string"), "yyyyMMdd")
    )
)

# %% [markdown]
# ## Sales and Price Corrections

# %%
df = (
    df
    .withColumn(
        "sls_price",
        F.when(
            (col("sls_price").isNull()) | (col("sls_price") <= 0),
            F.when(
                col("sls_quantity") != 0,
                col("sls_sales") / col("sls_quantity")
            ).otherwise(None)
        ).otherwise(col("sls_price"))
    )
)

# %% [markdown]
# ## Renaming Columns

# %%
RENAME_MAP = {
    "sls_ord_num": "order_number",
    "sls_prd_key": "product_key",
    "sls_cust_id": "customer_id",
    "sls_order_dt": "order_date",
    "sls_ship_dt": "ship_date",
    "sls_due_dt": "due_date",
    "sls_sales": "sales",
    "sls_quantity": "quantity",
    "sls_price": "price",
}

for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name, new_name)

# %% [markdown]
# # Writing Silver Table

# %%
(
    df.write
    .mode("overwrite")
    .format("delta")
    .saveAsTable("silver.crm_sales")
)

# %%
# %sql
SELECT * FROM workspace.silver.crm_sales
