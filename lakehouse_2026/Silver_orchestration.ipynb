# %% [markdown]
# # Silver Layer Orchestration

# %%
notebooks = [
    "/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Silver/Silver_crm_cust_info",
    "/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Silver/Silver_crm_prd_info",
    "/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Silver/Silver_crm_sales_details",
    "/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Silver/Silver_erp_cust_az12",
    "/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Silver/Silver_erp_loc_a101",
    "/Users/jovitabeliak@gmail.com/DataBricks_project/lakehouse_2026/Silver/Silver_erp_px_cat_g1v2"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
